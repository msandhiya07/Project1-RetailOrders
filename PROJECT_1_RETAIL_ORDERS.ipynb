# %% [markdown]
# <a href="https://colab.research.google.com/github/msandhiya07/Project1-RetailOrders/blob/main/PROJECT_1_RETAIL_ORDERS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROJECT 1-RETAIL_ORDERS

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c75dbf9c-0aaf-4344-a0bf-379c82b6d49e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c75dbf9c-0aaf-4344-a0bf-379c82b6d49e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle  #making new dir
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle(1).json ~/.kaggle/  #copying JSON to the dir
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: ` cp kaggle(1).json ~/.kaggle/  #copying JSON to the dir'

# %%
! chmod 600 ~/.kaggle/kaggle(1).json   #permission to owner only
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: ` chmod 600 ~/.kaggle/kaggle(1).json   #permission to owner only'

# %%
# !kaggle -h
# Out:
# usage: kaggle [-h] [-v] [-W] {competitions,c,datasets,d,kernels,k,models,m,files,f,config} ...
#
# options:
#   -h, --help            show this help message and exit
#   -v, --version         Print the Kaggle API version
#   -W, --no-warn         Disable out-of-date API version warning
#
# commands:
#   {competitions,c,datasets,d,kernels,k,models,m,files,f,config}
#                         Use one of:
#                         competitions {list, files, download, submit, submissions, leaderboard}
#                         datasets {list, files, download, create, version, init, metadata, status}
#                         kernels {list, files, init, push, pull, output, status}
#                         models {instances, get, list, init, create, delete, update}
#                         models instances {versions, get, files, init, create, delete, update}
#                         models instances versions {init, create, download, delete, files}
# ...

# %%
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# ...
#   0% 0.00/200k [00:00<?, ?B/s]
# 100% 200k/200k [00:00<00:00, 107MB/s]

# %%
# !unzip //content/orders.csv.zip
# Out:
# Archive:  //content/orders.csv.zip
#   inflating: orders.csv

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("orders.csv")
df.head()
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df.shape
# Out:
# (9994, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Id          9994 non-null   int64
#  1   Order Date        9994 non-null   object
#  2   Ship Mode         9993 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub Category      9994 non-null   object
#  11  Product Id        9994 non-null   object
#  12  cost price        9994 non-null   int64
#  13  List Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount Percent  9994 non-null   int64
# dtypes: int64(6), object(10)
# ...

# %%
df.describe()
# Out:
#           Order Id   Postal Code    cost price    List Price     Quantity  \
# count  9994.000000   9994.000000   9994.000000   9994.000000  9994.000000
# mean   4997.500000  55190.379428    201.189714    229.756854     3.789574
# std    2885.163629  32063.693350    537.743203    623.245839     2.225110
# min       1.000000   1040.000000      0.000000      0.000000     1.000000
# 25%    2499.250000  23223.000000     20.000000     20.000000     2.000000
# 50%    4997.500000  56430.500000     50.000000     50.000000     3.000000
# 75%    7495.750000  90008.000000    180.000000    210.000000     5.000000
# max    9994.000000  99301.000000  18110.000000  22640.000000    14.000000
#
#        Discount Percent
# count       9994.000000
# mean           3.484090
# std            1.114211
# min            2.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

df.to_csv('/content/updated_orders.csv', index=False)

print("Trailing spaces removed and saved as '/content/updated_orders.csv'.")
# Out:
# Trailing spaces removed and saved as '/content/updated_orders.csv'.
# <ipython-input-20-60bd17155d3d>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df.columns
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Order Id            0
# Order Date          0
# Ship Mode           1
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Category            0
# Sub Category        0
# Product Id          0
# cost price          0
# List Price          0
# Quantity            0
# Discount Percent    0
# dtype: int64

# %%
df.dropna()
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df.fillna(0)
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df.head()
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df.columns.str.lower()
# Out:
# Index(['order id', 'order date', 'ship mode', 'segment', 'country', 'city',
#        'state', 'postal code', 'region', 'category', 'sub category',
#        'product id', 'cost price', 'list price', 'quantity',
#        'discount percent'],
#       dtype='object')

# %%
df.rename(columns={'Order Id':'order_id','Order Date':'order_date','Ship Mode':'ship_mode','Sub Category':'sub_category','Category':'category',
                   'Product Id':'product_id', 'Postal Code':'postal_code','cost price':'cost_price','Region':'region','State':'state','Quantity':'quantity',
                   'List Price':'list_price','Discount Percent':'discount_percent','Segment':'segment','Country':'country','City':'city'
                   },inplace=True)
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df['discount'] = df['cost_price'] - df['list_price']
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df['sale_price'] = df['cost_price'] * (1 - df['discount_percent'] / 100)
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
# Assuming the dataset contains a 'Cost Price' column
df['profit'] = df['list_price'] - df['cost_price']
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df.to_csv('updated_orders.csv', index=False)
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df.to_csv("Retail_Orders.csv",index=False)
print("Data saved to 'Retail_Orders.csv'")
# Out:
# Data saved to 'Retail_Orders.csv'

# %%
df.to_excel("Retail_Orders.xlsx",index=False)
print("Data saved to 'Retail_Orders.xlsx'")
# Out:
# Data saved to 'Retail_Orders.xlsx'

# %%
from google.colab import files
files.download("Retail_Orders.csv")
files.download("Retail_Orders.xlsx")

# %%
file_path='/content/Retail_Orders.csv'
Retail_Orders1=pd.read_csv(file_path)

# %%
primary_key_columns=['order_id']
split_1_columns=primary_key_columns+list(Retail_Orders1.columns[1:10])
split_2_columns=primary_key_columns+list(Retail_Orders1.columns[10:])

# %%
table_1=Retail_Orders1[split_1_columns]
table_2=Retail_Orders1[split_2_columns]

# %%
print("TABLE1 COLUMNS:",table_1.columns)
print("TABLE2 COLUMNS:",table_2.columns)
# Out:
# TABLE1 COLUMNS: Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category'],
#       dtype='object')
# TABLE2 COLUMNS: Index(['order_id', 'sub_category', 'product_id', 'cost_price', 'list_price',
#        'quantity', 'discount_percent', 'discount', 'sale_price', 'profit'],
#       dtype='object')

# %%
table_1
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category
# ...

# %%
table_2
# Out:
#       order_id sub_category       product_id  cost_price  list_price  \
# 0            1    Bookcases  FUR-BO-10001798         240         260
# 1            2       Chairs  FUR-CH-10000454         600         730
# 2            3       Labels  OFF-LA-10000240          10          10
# 3            4       Tables  FUR-TA-10000577         780         960
# 4            5      Storage  OFF-ST-10000760          20          20
# ...        ...          ...              ...         ...         ...
# 9989      9990  Furnishings  FUR-FU-10001889          30          30
# 9990      9991  Furnishings  FUR-FU-10000747          70          90
# 9991      9992       Phones  TEC-PH-10003645         220         260
# 9992      9993        Paper  OFF-PA-10004041          30          30
# 9993      9994   Appliances  OFF-AP-10002684         210         240
#
#       quantity  discount_percent  discount  sale_price  profit
# 0            2                 2       -20       235.2      20
# ...

# %%
df.to_csv("table_1.csv",index=False)
print("Data saved to 'table_1.csv'")
# Out:
# Data saved to 'table_1.csv'

# %%
df.to_csv("table_2.csv",index=False)
print("Data saved to 'table_2.csv'")
# Out:
# Data saved to 'table_2.csv'

# %%
df.to_excel("table_1.xlsx",index=False)
print("Data saved to 'table_1.xlsx'")
# Out:
# Data saved to 'table_1.xlsx'

# %%
df.to_excel("table_2.xlsx",index=False)
print("Data saved to 'table_2.xlsx'")
# Out:
# Data saved to 'table_2.xlsx'

# %%
from google.colab import files
files.download("table_1.csv")
files.download("table_1.xlsx")
files.download("table_2.csv")
files.download("table_2.xlsx")

# %%
pip install pandas sqlalchemy pyodbc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.0/336.0 kB 6.9 MB/s eta 0:00:00
# ...
